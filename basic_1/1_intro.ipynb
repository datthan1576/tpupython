# %%
import math

x = float(input("Enter x :"))
y = float(input("Enter y :"))
z = float(input("Enter z :"))
if (z+x**2/4)!=0:
    a1 = y - math.sqrt(abs(x))
    a2 = x - (y / (z + (x ** 2) / 4))
    k = math.log(abs(a1 * a2))
    print("k =", k)
else:
    print("k doesn't exist!")


a3 = (math.cos(x - (math.pi) / 6)) / (1 / 2 + (math.sin(y)) ** 2)
a4 = abs(y - x) / 3
d = a3 + a4
print("d=", d)

a5 = (x / y) * (z + x) * (math.exp(abs(x - y))) + math.log(1 + math.exp(1))
a6 = (math.sin(y) ** 2) - (math.sin(x) * math.sin(y)) ** 2
if a6!=0:
    w = a5 / a6
    print("w=", w)
else:
    print("w doesn't exist!")


g = 3 + math.exp(y - 1)
h = 1 + (x ** 2) * abs(y - math.tan(z))
if h!=0:
    b = g / h
    print("b=", b)
else:
    print("b doesnt' exist!")
# Out:
# Enter x :3
# Enter y :5
# Enter z :6
# k = 2.0571029208857414
# d= 0.11240190825955687
# w= 45.731355059540036
# b= 1.1846826141983875

# %%
a = float(input("Enter a:"))
b = float(input("Enter b:"))
c = float(input("Enter c:"))
x = float(input("Enter x:"))
y = float(input("Enter y:"))

p = 0
if a * b < -2:
    p = math.sqrt(abs(a * b)) + 2 * c
elif -2 <= a * b <= 2:
    p = a ** 3 + b ** 2 - c ** -2
elif a * b > 2:
    p = a ** c - b
print("p=", p)

H = 0
if x < y:
    H = math.atan(x + abs(y))
elif x > y:
    H = math.atan(y + abs(x))
elif x == y:
    H = (x + y) ** 2
print("H=", H)

B = 0
if x / y > 0:
    B = math.log(x / y) + (x ** 2 + y) ** 3
elif x / y < 0:
    B = math.log(abs(x / y)) + (x ** 2 + y) ** 3
elif x == 0 and y != 0:
    B = (x ** 2 + y) ** 3
print("B=", B)

B1 = 0
if x - y > 0:
    B1 = math.sin(x + y) + 2 * (x + y) ** 2
elif x - y < 0:
    B1 = math.sin(x - y) + (x * y) ** 3
elif x == 0 and y != 0:
    B1 = abs(x ** 2 + math.sqrt(y))
elif y == 0:
    B1 = 0
print("B1=", B1)
# Out:
# Enter a:2
# Enter b:4
# Enter c:5
# Enter x:3
# Enter y:7
# p= 28.0
# H= 1.4711276743037347
# B= 4095.1527021396128
# B1= 9261.756802495307
